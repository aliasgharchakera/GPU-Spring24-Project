# %%
# %pip install taichi numpy --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
for i in [10,100,200,500,1000]:
    for j in [100,500,1000,10000,50000,100000]:
        # !python tsp.py $j $i 0.4
# Out:
# [Taichi] version 1.7.1, llvm 15.0.4, commit 0f143b2f, linux, python 3.11.5
# [Taichi] Starting on arch=x64
# for generation 100
# [W 05/04/24 19:27:13.734 292808]
# Assign may lose precision: unknown <- i32
# Traceback (most recent call last):
#   File "/home/rk06451/gpu/gpu-spring24-project/tsp.py", line 224, in <module>
#     init_population()
#   File "/home/rk06451/gpu/gpu-spring24-project/tsp.py", line 33, in init_population
#     shuffle(i)
#   File "/home/rk06451/gpu/gpu-spring24-project/tsp.py", line 41, in shuffle
#     j = ti.random(ti.int32) % (i + 1)
#         ^^^^^^^^^^^^^^^^^^^
#   File "/home/rk06451/.local/lib/python3.11/site-packages/taichi/lang/ops.py", line 594, in random
#     x = expr.Expr(_ti_core.make_rand_expr(dtype, _ti_core.DebugInfo(impl.get_runtime().get_current_src_info())))
#                                                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
